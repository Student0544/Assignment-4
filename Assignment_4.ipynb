# %% [markdown]
# Mount the drive

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# Download the relevant files

# %%
! gdown --id 17V5zE73X6uySSS7-ay7lrgh5VOZkJR0Y # test images
! gdown --id 1lVVphSGxfo-tJRgf13Dh9c3lEJzYFD1s # train images
! gdown --id 1IRTxGio5SNfiIGXIfMD91kZRL7i6CVSM # train labels
# Out:
# /usr/local/lib/python3.9/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=17V5zE73X6uySSS7-ay7lrgh5VOZkJR0Y
# To: /content/test_images.npy
# 100% 62.7M/62.7M [00:00<00:00, 137MB/s]
# /usr/local/lib/python3.9/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1lVVphSGxfo-tJRgf13Dh9c3lEJzYFD1s
# To: /content/train_images.npy
# 100% 157M/157M [00:01<00:00, 116MB/s]
# /usr/local/lib/python3.9/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1IRTxGio5SNfiIGXIfMD91kZRL7i6CVSM
# To: /content/train_labels.csv
# 100% 439k/439k [00:00<00:00, 38.8MB/s]

# %% [markdown]
# Set up the fixed variables, functions and classes

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import torch.cuda
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torch.optim as optim

batch_size = 10
train_images = np.load("train_images.npy")
train_labels = pd.read_csv("train_labels.csv")['label']
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
epochs = 15
label_str = {0: 'T-shirt/Top', 1: 'Trouser', 2: 'Pullover', 3: 'Dress', 4: 'Coat', 5: 'Sandal', 6: 'Shirt',
             7: 'Sneaker', 8: 'Bag', 9: 'Ankle Boot'}
test_images = np.load("test_images.npy")

def show_image(arr):
    two_d = (np.reshape(arr, (28, 28)) * 255).astype(np.uint8)
    plt.imshow(two_d, interpolation='nearest')
    plt.show()

class MNIST(Dataset):
    def __init__(self, data, labels):
        self.x = data
        self.y = labels
        self.n_samples = len(data)

    def __len__(self):
        return self.n_samples

    def __getitem__(self, index):
        return torch.from_numpy(self.x[index]).unsqueeze(0).float() / 255, self.y[index]


class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()

        self.layer1 = nn.Sequential(
            nn.Conv2d(in_channels=1, out_channels=32, kernel_size=3, padding=1),
            nn.BatchNorm2d(32), nn.ReLU(), nn.MaxPool2d(kernel_size=2, stride=2))
        
        self.layer2 = nn.Sequential(
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3),
            nn.BatchNorm2d(64), nn.ReLU(), nn.MaxPool2d(2))
        
        self.fc1 = nn.Linear(in_features=64*6*6, out_features=600)
        self.drop = nn.Dropout2d(0.25)
        self.fc2 = nn.Linear(in_features=600, out_features=120)
        self.fc3 = nn.Linear(in_features=120, out_features=10)

    def forward(self, x):
        out = self.layer1(x)
        out = self.layer2(out)
        out = out.view(out.size(0), -1)
        out = self.fc1(out)
        out = self.drop(out)
        out = self.fc2(out)
        out = self.fc3(out)
        
        return out

# %% [markdown]
# Set up the model and its hyperparameters

# %%
training_dataset = MNIST(train_images, train_labels)
dataloader = DataLoader(dataset=training_dataset, batch_size=batch_size, shuffle=True)
model = CNN()
model.to(device)
learning_rate = 0.0005

model.train()
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %% [markdown]
# Train the model

# %%
for epoch in range(1, epochs+1):
    t_loss = 0
    t_correct = 0
    accuracies = []

    for image, label in dataloader:
        image = image.to(device)
        label = label.to(device)

        prediction = model(image)
        loss = criterion(prediction, label)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        t_loss += loss.item()
        t_correct += prediction.argmax(dim=1).eq(label).sum().item()
        accuracy = t_correct * 100 / len(training_dataset)
        print("Epoch no.", epoch, "|accuracy: ", round(accuracy, 3), "%", "|total_loss: ", t_loss)
# Out:
# /usr/local/lib/python3.9/dist-packages/torch/nn/functional.py:1331: UserWarning: dropout2d: Received a 2-D input to dropout2d, which is deprecated and will result in an error in a future release. To retain the behavior and silence this warning, please use dropout instead. Note that dropout2d exists to provide channel-wise dropout on inputs with 2 spatial dimensions, a channel dimension, and an optional batch dimension (i.e. 3D or 4D inputs).
#   warnings.warn(warn_msg)
# Streaming output truncated to the last 5000 lines.
# Epoch no. 15 |accuracy:  0.02 % |total_loss:  0.06820086389780045
# Epoch no. 15 |accuracy:  0.038 % |total_loss:  0.29717301577329636
# Epoch no. 15 |accuracy:  0.056 % |total_loss:  0.4548647925257683
# Epoch no. 15 |accuracy:  0.074 % |total_loss:  0.6094824597239494
# Epoch no. 15 |accuracy:  0.094 % |total_loss:  0.6932595670223236
# Epoch no. 15 |accuracy:  0.112 % |total_loss:  0.8037374168634415
# Epoch no. 15 |accuracy:  0.13 % |total_loss:  1.0170786529779434
# Epoch no. 15 |accuracy:  0.15 % |total_loss:  1.0434050373733044
# Epoch no. 15 |accuracy:  0.168 % |total_loss:  1.2851071916520596
# Epoch no. 15 |accuracy:  0.188 % |total_loss:  1.3131582494825125
# Epoch no. 15 |accuracy:  0.204 % |total_loss:  1.691774046048522
# Epoch no. 15 |accuracy:  0.224 % |total_loss:  1.759008077904582
# Epoch no. 15 |accuracy:  0.244 % |total_loss:  1.771407756023109
# Epoch no. 15 |accuracy:  0.264 % |total_loss:  1.8193775741383433
# Epoch no. 15 |accuracy:  0.284 % |total_loss:  1.8328579887747765
# Epoch no. 15 |accuracy:  0.302 % |total_loss:  1.9735423550009727
# Epoch no. 15 |accuracy:  0.32 % |total_loss:  2.1338314339518547
# Epoch no. 15 |accuracy:  0.338 % |total_loss:  2.4294260665774345
# Epoch no. 15 |accuracy:  0.356 % |total_loss:  2.561131037771702
# Epoch no. 15 |accuracy:  0.374 % |total_loss:  2.715191565454006
# Epoch no. 15 |accuracy:  0.394 % |total_loss:  2.7459956239908934
# Epoch no. 15 |accuracy:  0.414 % |total_loss:  2.8266579639166594
# Epoch no. 15 |accuracy:  0.434 % |total_loss:  2.841261693276465
# Epoch no. 15 |accuracy:  0.454 % |total_loss:  2.970276736654341
# Epoch no. 15 |accuracy:  0.474 % |total_loss:  3.046730794943869
# Epoch no. 15 |accuracy:  0.488 % |total_loss:  3.6518242144957185
# Epoch no. 15 |accuracy:  0.506 % |total_loss:  3.837945722974837
# Epoch no. 15 |accuracy:  0.526 % |total_loss:  3.849017999134958
# Epoch no. 15 |accuracy:  0.546 % |total_loss:  4.001594773493707
# Epoch no. 15 |accuracy:  0.566 % |total_loss:  4.1546986466273665
# Epoch no. 15 |accuracy:  0.586 % |total_loss:  4.198018963448703
# Epoch no. 15 |accuracy:  0.606 % |total_loss:  4.261992539279163
# Epoch no. 15 |accuracy:  0.626 % |total_loss:  4.300491559319198
# Epoch no. 15 |accuracy:  0.642 % |total_loss:  4.615203249268234
# Epoch no. 15 |accuracy:  0.662 % |total_loss:  4.648060324601829
# Epoch no. 15 |accuracy:  0.68 % |total_loss:  4.819787937216461
# Epoch no. 15 |accuracy:  0.698 % |total_loss:  5.023905741982162
# Epoch no. 15 |accuracy:  0.714 % |total_loss:  5.273428755812347
# Epoch no. 15 |accuracy:  0.732 % |total_loss:  5.55966894607991
# Epoch no. 15 |accuracy:  0.75 % |total_loss:  5.72021650057286
# Epoch no. 15 |accuracy:  0.77 % |total_loss:  5.8950381157919765
# Epoch no. 15 |accuracy:  0.788 % |total_loss:  6.076366323046386
# Epoch no. 15 |accuracy:  0.808 % |total_loss:  6.139745670370758
# Epoch no. 15 |accuracy:  0.828 % |total_loss:  6.147909082472324
# Epoch no. 15 |accuracy:  0.848 % |total_loss:  6.1731664724648
# Epoch no. 15 |accuracy:  0.866 % |total_loss:  6.4749462492764
# Epoch no. 15 |accuracy:  0.884 % |total_loss:  6.583415891975164
# Epoch no. 15 |accuracy:  0.902 % |total_loss:  6.810365315526724
# Epoch no. 15 |accuracy:  0.92 % |total_loss:  6.911886591464281
# Epoch no. 15 |accuracy:  0.938 % |total_loss:  7.2194999642670155
# Epoch no. 15 |accuracy:  0.956 % |total_loss:  7.521123606711626
# Epoch no. 15 |accuracy:  0.976 % |total_loss:  7.595391731709242
# Epoch no. 15 |accuracy:  0.994 % |total_loss:  7.771758150309324
# Epoch no. 15 |accuracy:  1.012 % |total_loss:  8.54234404489398
# Epoch no. 15 |accuracy:  1.032 % |total_loss:  8.666593421250582
# Epoch no. 15 |accuracy:  1.05 % |total_loss:  8.816406387835741
# Epoch no. 15 |accuracy:  1.07 % |total_loss:  8.915901187807322
# Epoch no. 15 |accuracy:  1.088 % |total_loss:  9.094320986419916
# Epoch no. 15 |accuracy:  1.108 % |total_loss:  9.255860317498446
# Epoch no. 15 |accuracy:  1.128 % |total_loss:  9.30159455537796
# Epoch no. 15 |accuracy:  1.142 % |total_loss:  9.717331230640411
# Epoch no. 15 |accuracy:  1.16 % |total_loss:  9.841881848871708
# Epoch no. 15 |accuracy:  1.18 % |total_loss:  9.848818912170827
# Epoch no. 15 |accuracy:  1.2 % |total_loss:  9.960545591078699
# Epoch no. 15 |accuracy:  1.22 % |total_loss:  10.056073672138155
# Epoch no. 15 |accuracy:  1.24 % |total_loss:  10.149979612790048
# Epoch no. 15 |accuracy:  1.256 % |total_loss:  10.596291563473642
# Epoch no. 15 |accuracy:  1.276 % |total_loss:  10.716676815412939
# Epoch no. 15 |accuracy:  1.296 % |total_loss:  10.80492018070072
# Epoch no. 15 |accuracy:  1.314 % |total_loss:  11.015098228119314
# Epoch no. 15 |accuracy:  1.334 % |total_loss:  11.019300813786685
# Epoch no. 15 |accuracy:  1.354 % |total_loss:  11.048553197644651
# Epoch no. 15 |accuracy:  1.372 % |total_loss:  11.234707652591169
# Epoch no. 15 |accuracy:  1.392 % |total_loss:  11.300461648963392
# Epoch no. 15 |accuracy:  1.41 % |total_loss:  11.411974652670324
# Epoch no. 15 |accuracy:  1.43 % |total_loss:  11.466220921836793
# Epoch no. 15 |accuracy:  1.45 % |total_loss:  11.480246496386826
# Epoch no. 15 |accuracy:  1.466 % |total_loss:  11.70253072399646
# Epoch no. 15 |accuracy:  1.484 % |total_loss:  11.837112468667328
# Epoch no. 15 |accuracy:  1.504 % |total_loss:  11.886920561082661
# Epoch no. 15 |accuracy:  1.524 % |total_loss:  11.912879182957113
# Epoch no. 15 |accuracy:  1.542 % |total_loss:  12.024796857498586
# Epoch no. 15 |accuracy:  1.562 % |total_loss:  12.028643854428083
# Epoch no. 15 |accuracy:  1.576 % |total_loss:  12.575936504174024
# Epoch no. 15 |accuracy:  1.596 % |total_loss:  12.605009915772825
# Epoch no. 15 |accuracy:  1.616 % |total_loss:  12.653155575040728
# Epoch no. 15 |accuracy:  1.636 % |total_loss:  12.796095991972834
# Epoch no. 15 |accuracy:  1.656 % |total_loss:  12.848702693823725
# Epoch no. 15 |accuracy:  1.676 % |total_loss:  12.88254107022658
# Epoch no. 15 |accuracy:  1.696 % |total_loss:  12.8888472430408
# Epoch no. 15 |accuracy:  1.716 % |total_loss:  12.906537231057882
# Epoch no. 15 |accuracy:  1.736 % |total_loss:  12.938419792801142
# Epoch no. 15 |accuracy:  1.756 % |total_loss:  12.94766285456717
# Epoch no. 15 |accuracy:  1.776 % |total_loss:  12.95203202450648
# Epoch no. 15 |accuracy:  1.794 % |total_loss:  13.13506659353152
# Epoch no. 15 |accuracy:  1.814 % |total_loss:  13.174081000033766
# Epoch no. 15 |accuracy:  1.834 % |total_loss:  13.242619256023318
# Epoch no. 15 |accuracy:  1.854 % |total_loss:  13.324897112790495
# Epoch no. 15 |accuracy:  1.874 % |total_loss:  13.385290993843228
# Epoch no. 15 |accuracy:  1.894 % |total_loss:  13.430804076138884
# Epoch no. 15 |accuracy:  1.914 % |total_loss:  13.442826059181243
# Epoch no. 15 |accuracy:  1.934 % |total_loss:  13.451616434846073
# Epoch no. 15 |accuracy:  1.952 % |total_loss:  13.707644341979176
# Epoch no. 15 |accuracy:  1.972 % |total_loss:  13.832900448236614
# Epoch no. 15 |accuracy:  1.992 % |total_loss:  13.855270583648235
# Epoch no. 15 |accuracy:  2.008 % |total_loss:  14.427025694865733
# Epoch no. 15 |accuracy:  2.028 % |total_loss:  14.466784891206771
# Epoch no. 15 |accuracy:  2.046 % |total_loss:  14.647526588756591
# Epoch no. 15 |accuracy:  2.066 % |total_loss:  14.689553816337138
# Epoch no. 15 |accuracy:  2.086 % |total_loss:  14.784322981256992
# Epoch no. 15 |accuracy:  2.104 % |total_loss:  15.08557838620618
# Epoch no. 15 |accuracy:  2.122 % |total_loss:  15.354917470831424
# Epoch no. 15 |accuracy:  2.14 % |total_loss:  15.526606057304889
# Epoch no. 15 |accuracy:  2.16 % |total_loss:  15.533092142548412
# Epoch no. 15 |accuracy:  2.178 % |total_loss:  15.712801636662334
# Epoch no. 15 |accuracy:  2.198 % |total_loss:  15.760112585034221
# Epoch no. 15 |accuracy:  2.216 % |total_loss:  15.932901562657207
# Epoch no. 15 |accuracy:  2.236 % |total_loss:  16.020054617431015
# Epoch no. 15 |accuracy:  2.256 % |total_loss:  16.023630696348846
# Epoch no. 15 |accuracy:  2.276 % |total_loss:  16.12948116939515
# Epoch no. 15 |accuracy:  2.296 % |total_loss:  16.166331253014505
# Epoch no. 15 |accuracy:  2.314 % |total_loss:  16.655224761925638
# Epoch no. 15 |accuracy:  2.332 % |total_loss:  17.232423684559762
# Epoch no. 15 |accuracy:  2.352 % |total_loss:  17.33935314323753
# Epoch no. 15 |accuracy:  2.372 % |total_loss:  17.36390181723982
# Epoch no. 15 |accuracy:  2.388 % |total_loss:  17.96100863162428
# Epoch no. 15 |accuracy:  2.406 % |total_loss:  18.15684548858553
# Epoch no. 15 |accuracy:  2.426 % |total_loss:  18.161842952948064
# Epoch no. 15 |accuracy:  2.444 % |total_loss:  18.393487777095288
# Epoch no. 15 |accuracy:  2.464 % |total_loss:  18.40138523792848
# Epoch no. 15 |accuracy:  2.478 % |total_loss:  19.115107288118452
# Epoch no. 15 |accuracy:  2.49 % |total_loss:  19.904602100607008
# Epoch no. 15 |accuracy:  2.506 % |total_loss:  20.240151723381132
# Epoch no. 15 |accuracy:  2.526 % |total_loss:  20.27120721479878
# Epoch no. 15 |accuracy:  2.544 % |total_loss:  20.411473543848842
# Epoch no. 15 |accuracy:  2.564 % |total_loss:  20.45270034437999
# Epoch no. 15 |accuracy:  2.582 % |total_loss:  20.60862242942676
# Epoch no. 15 |accuracy:  2.598 % |total_loss:  20.97863140469417
# Epoch no. 15 |accuracy:  2.616 % |total_loss:  21.31109139090404
# Epoch no. 15 |accuracy:  2.636 % |total_loss:  21.32013130420819
# Epoch no. 15 |accuracy:  2.652 % |total_loss:  22.3087347173132
# Epoch no. 15 |accuracy:  2.672 % |total_loss:  22.38081386173144
# Epoch no. 15 |accuracy:  2.692 % |total_loss:  22.408122454304248
# Epoch no. 15 |accuracy:  2.712 % |total_loss:  22.41319352760911
# Epoch no. 15 |accuracy:  2.732 % |total_loss:  22.43067902699113
# Epoch no. 15 |accuracy:  2.752 % |total_loss:  22.495420161634684
# Epoch no. 15 |accuracy:  2.77 % |total_loss:  22.641598913818598
# Epoch no. 15 |accuracy:  2.79 % |total_loss:  22.687896218150854
# Epoch no. 15 |accuracy:  2.808 % |total_loss:  22.967345889657736
# Epoch no. 15 |accuracy:  2.826 % |total_loss:  23.106461372226477
# Epoch no. 15 |accuracy:  2.844 % |total_loss:  23.21217718347907
# Epoch no. 15 |accuracy:  2.864 % |total_loss:  23.228603027760983
# Epoch no. 15 |accuracy:  2.884 % |total_loss:  23.286125242710114
# Epoch no. 15 |accuracy:  2.904 % |total_loss:  23.29171850392595
# Epoch no. 15 |accuracy:  2.922 % |total_loss:  23.404174825642258
# Epoch no. 15 |accuracy:  2.936 % |total_loss:  23.890152803156525
# Epoch no. 15 |accuracy:  2.956 % |total_loss:  23.940833183471113
# Epoch no. 15 |accuracy:  2.974 % |total_loss:  24.146132367197424
# Epoch no. 15 |accuracy:  2.992 % |total_loss:  24.35116075212136
# Epoch no. 15 |accuracy:  3.01 % |total_loss:  24.59369935328141
# Epoch no. 15 |accuracy:  3.026 % |total_loss:  24.83189875120297
# Epoch no. 15 |accuracy:  3.046 % |total_loss:  24.85569227533415
# Epoch no. 15 |accuracy:  3.066 % |total_loss:  24.881843926850706
# Epoch no. 15 |accuracy:  3.086 % |total_loss:  24.907878054771572
# Epoch no. 15 |accuracy:  3.104 % |total_loss:  25.024246788118035
# Epoch no. 15 |accuracy:  3.122 % |total_loss:  25.187712287995964
# Epoch no. 15 |accuracy:  3.142 % |total_loss:  25.20830087037757
# Epoch no. 15 |accuracy:  3.162 % |total_loss:  25.29840847523883
# Epoch no. 15 |accuracy:  3.18 % |total_loss:  25.457707640249282
# Epoch no. 15 |accuracy:  3.2 % |total_loss:  25.57016559364274
# Epoch no. 15 |accuracy:  3.218 % |total_loss:  25.68693891586736
# Epoch no. 15 |accuracy:  3.236 % |total_loss:  25.83225590409711
# Epoch no. 15 |accuracy:  3.256 % |total_loss:  25.90489846887067
# Epoch no. 15 |accuracy:  3.274 % |total_loss:  26.16300189914182
# Epoch no. 15 |accuracy:  3.294 % |total_loss:  26.22665158333257
# Epoch no. 15 |accuracy:  3.314 % |total_loss:  26.296693552751094
# Epoch no. 15 |accuracy:  3.334 % |total_loss:  26.30505224270746
# Epoch no. 15 |accuracy:  3.354 % |total_loss:  26.32964008441195
# Epoch no. 15 |accuracy:  3.372 % |total_loss:  26.62064861645922
# Epoch no. 15 |accuracy:  3.392 % |total_loss:  26.634370371233672
# Epoch no. 15 |accuracy:  3.412 % |total_loss:  26.687996200751513
# Epoch no. 15 |accuracy:  3.43 % |total_loss:  26.804046980571
# Epoch no. 15 |accuracy:  3.45 % |total_loss:  26.90113543672487
# Epoch no. 15 |accuracy:  3.47 % |total_loss:  26.92932634195313
# Epoch no. 15 |accuracy:  3.488 % |total_loss:  27.05194100132212
# Epoch no. 15 |accuracy:  3.508 % |total_loss:  27.164185227360576
# Epoch no. 15 |accuracy:  3.524 % |total_loss:  27.43580508371815
# Epoch no. 15 |accuracy:  3.544 % |total_loss:  27.54722317447886
# Epoch no. 15 |accuracy:  3.564 % |total_loss:  27.67156792571768
# Epoch no. 15 |accuracy:  3.58 % |total_loss:  27.8619561730884
# Epoch no. 15 |accuracy:  3.6 % |total_loss:  27.93537095328793
# Epoch no. 15 |accuracy:  3.618 % |total_loss:  28.11520797153935
# Epoch no. 15 |accuracy:  3.638 % |total_loss:  28.134352534543723
# Epoch no. 15 |accuracy:  3.658 % |total_loss:  28.214518457185477
# Epoch no. 15 |accuracy:  3.676 % |total_loss:  28.388064220082015
# Epoch no. 15 |accuracy:  3.694 % |total_loss:  28.586151405703276
# Epoch no. 15 |accuracy:  3.712 % |total_loss:  28.976655169855803
# Epoch no. 15 |accuracy:  3.728 % |total_loss:  29.164371475111693
# Epoch no. 15 |accuracy:  3.748 % |total_loss:  29.30232323659584
# Epoch no. 15 |accuracy:  3.766 % |total_loss:  29.428545534145087
# Epoch no. 15 |accuracy:  3.784 % |total_loss:  29.659930049907416
# Epoch no. 15 |accuracy:  3.804 % |total_loss:  29.699105984997004
# Epoch no. 15 |accuracy:  3.822 % |total_loss:  29.857954538892955
# Epoch no. 15 |accuracy:  3.842 % |total_loss:  29.91120399488136
# Epoch no. 15 |accuracy:  3.862 % |total_loss:  29.95851758820936
# Epoch no. 15 |accuracy:  3.882 % |total_loss:  30.02805235935375
# Epoch no. 15 |accuracy:  3.902 % |total_loss:  30.067769083660096
# Epoch no. 15 |accuracy:  3.922 % |total_loss:  30.08758295280859
# Epoch no. 15 |accuracy:  3.94 % |total_loss:  30.215689949225634
# Epoch no. 15 |accuracy:  3.96 % |total_loss:  30.276697497349232
# Epoch no. 15 |accuracy:  3.98 % |total_loss:  30.321931320708245
# Epoch no. 15 |accuracy:  4.0 % |total_loss:  30.387705664616078
# Epoch no. 15 |accuracy:  4.02 % |total_loss:  30.39905805652961
# Epoch no. 15 |accuracy:  4.04 % |total_loss:  30.405872464645654
# Epoch no. 15 |accuracy:  4.06 % |total_loss:  30.444505829829723
# Epoch no. 15 |accuracy:  4.08 % |total_loss:  30.478902858216316
# Epoch no. 15 |accuracy:  4.1 % |total_loss:  30.513766285497695
# Epoch no. 15 |accuracy:  4.12 % |total_loss:  30.559831321705133
# Epoch no. 15 |accuracy:  4.14 % |total_loss:  30.568256739061326
# Epoch no. 15 |accuracy:  4.16 % |total_loss:  30.58171480288729
# Epoch no. 15 |accuracy:  4.178 % |total_loss:  30.779271447565407
# Epoch no. 15 |accuracy:  4.198 % |total_loss:  30.819413842167705
# Epoch no. 15 |accuracy:  4.216 % |total_loss:  30.952100144233555
# Epoch no. 15 |accuracy:  4.236 % |total_loss:  30.996772137936205
# Epoch no. 15 |accuracy:  4.256 % |total_loss:  31.05445090821013
# Epoch no. 15 |accuracy:  4.274 % |total_loss:  31.270324343349785
# Epoch no. 15 |accuracy:  4.294 % |total_loss:  31.29346679477021
# Epoch no. 15 |accuracy:  4.314 % |total_loss:  31.335537183564156
# Epoch no. 15 |accuracy:  4.334 % |total_loss:  31.416977013926953
# Epoch no. 15 |accuracy:  4.354 % |total_loss:  31.527351449709386
# Epoch no. 15 |accuracy:  4.374 % |total_loss:  31.541963747236878
# Epoch no. 15 |accuracy:  4.39 % |total_loss:  31.87172909686342
# Epoch no. 15 |accuracy:  4.41 % |total_loss:  31.959336465690285
# Epoch no. 15 |accuracy:  4.43 % |total_loss:  32.10933122644201
# Epoch no. 15 |accuracy:  4.45 % |total_loss:  32.28063655504957
# Epoch no. 15 |accuracy:  4.47 % |total_loss:  32.286311365198344
# Epoch no. 15 |accuracy:  4.486 % |total_loss:  32.73237971169874
# Epoch no. 15 |accuracy:  4.504 % |total_loss:  33.04377940995619
# Epoch no. 15 |accuracy:  4.522 % |total_loss:  33.26210553152487
# Epoch no. 15 |accuracy:  4.542 % |total_loss:  33.29651964409277
# Epoch no. 15 |accuracy:  4.56 % |total_loss:  33.41920147789642
# Epoch no. 15 |accuracy:  4.58 % |total_loss:  33.57585158897564
# Epoch no. 15 |accuracy:  4.598 % |total_loss:  33.675008959602565
# Epoch no. 15 |accuracy:  4.616 % |total_loss:  33.85480651957914
# Epoch no. 15 |accuracy:  4.63 % |total_loss:  34.999055839609355
# Epoch no. 15 |accuracy:  4.648 % |total_loss:  35.36772430641577
# Epoch no. 15 |accuracy:  4.668 % |total_loss:  35.4011383051984
# Epoch no. 15 |accuracy:  4.688 % |total_loss:  35.50710602058098
# Epoch no. 15 |accuracy:  4.708 % |total_loss:  35.51192932436243
# Epoch no. 15 |accuracy:  4.726 % |total_loss:  35.64216715702787
# Epoch no. 15 |accuracy:  4.744 % |total_loss:  35.75573596218601
# Epoch no. 15 |accuracy:  4.762 % |total_loss:  35.95051886001602
# Epoch no. 15 |accuracy:  4.782 % |total_loss:  36.00836783880368
# Epoch no. 15 |accuracy:  4.802 % |total_loss:  36.014264991972595
# Epoch no. 15 |accuracy:  4.822 % |total_loss:  36.03851298475638
# Epoch no. 15 |accuracy:  4.842 % |total_loss:  36.09214882040396
# Epoch no. 15 |accuracy:  4.862 % |total_loss:  36.18418263876811
# Epoch no. 15 |accuracy:  4.882 % |total_loss:  36.18911056686193
# Epoch no. 15 |accuracy:  4.9 % |total_loss:  36.3858381556347
# Epoch no. 15 |accuracy:  4.918 % |total_loss:  36.48749013710767
# Epoch no. 15 |accuracy:  4.936 % |total_loss:  36.83502240944654
# Epoch no. 15 |accuracy:  4.954 % |total_loss:  37.07596962619573
# Epoch no. 15 |accuracy:  4.972 % |total_loss:  37.25550313759595
# Epoch no. 15 |accuracy:  4.992 % |total_loss:  37.31745931599289
# Epoch no. 15 |accuracy:  5.012 % |total_loss:  37.38950277213007
# Epoch no. 15 |accuracy:  5.032 % |total_loss:  37.500869893468916
# Epoch no. 15 |accuracy:  5.052 % |total_loss:  37.57519725803286
# Epoch no. 15 |accuracy:  5.072 % |total_loss:  37.58703044615686
# Epoch no. 15 |accuracy:  5.09 % |total_loss:  37.788006668910384
# Epoch no. 15 |accuracy:  5.11 % |total_loss:  37.807648649439216
# Epoch no. 15 |accuracy:  5.128 % |total_loss:  38.11937745474279
# Epoch no. 15 |accuracy:  5.146 % |total_loss:  38.32582815550268
# Epoch no. 15 |accuracy:  5.166 % |total_loss:  38.38650461100042
# Epoch no. 15 |accuracy:  5.186 % |total_loss:  38.42520281486213
# Epoch no. 15 |accuracy:  5.204 % |total_loss:  38.522290049120784
# Epoch no. 15 |accuracy:  5.224 % |total_loss:  38.57237242721021
# Epoch no. 15 |accuracy:  5.244 % |total_loss:  38.57942755613476
# Epoch no. 15 |accuracy:  5.262 % |total_loss:  38.668439478613436
# Epoch no. 15 |accuracy:  5.28 % |total_loss:  38.824285433627665
# Epoch no. 15 |accuracy:  5.298 % |total_loss:  39.096375540830195
# Epoch no. 15 |accuracy:  5.318 % |total_loss:  39.17485505435616
# Epoch no. 15 |accuracy:  5.334 % |total_loss:  39.57280188892037
# Epoch no. 15 |accuracy:  5.354 % |total_loss:  39.64689461980015
# Epoch no. 15 |accuracy:  5.374 % |total_loss:  39.660492287017405
# Epoch no. 15 |accuracy:  5.394 % |total_loss:  39.689586834050715
# Epoch no. 15 |accuracy:  5.414 % |total_loss:  39.762950950302184
# Epoch no. 15 |accuracy:  5.432 % |total_loss:  40.40819739643484
# Epoch no. 15 |accuracy:  5.45 % |total_loss:  40.52073231432587
# Epoch no. 15 |accuracy:  5.47 % |total_loss:  40.537818481214345
# Epoch no. 15 |accuracy:  5.49 % |total_loss:  40.61915285605937
# Epoch no. 15 |accuracy:  5.508 % |total_loss:  40.75893515069038
# Epoch no. 15 |accuracy:  5.526 % |total_loss:  40.89767572004348
# Epoch no. 15 |accuracy:  5.544 % |total_loss:  41.12225949484855
# Epoch no. 15 |accuracy:  5.564 % |total_loss:  41.12261879694415
# Epoch no. 15 |accuracy:  5.582 % |total_loss:  41.25148256373359
# Epoch no. 15 |accuracy:  5.6 % |total_loss:  41.443030538677704
# Epoch no. 15 |accuracy:  5.62 % |total_loss:  41.44317049240635
# Epoch no. 15 |accuracy:  5.64 % |total_loss:  41.450370153281256
# Epoch no. 15 |accuracy:  5.66 % |total_loss:  41.48822476142959
# Epoch no. 15 |accuracy:  5.676 % |total_loss:  41.839965658131405
# Epoch no. 15 |accuracy:  5.694 % |total_loss:  42.17649035328941
# Epoch no. 15 |accuracy:  5.714 % |total_loss:  42.253044726196094
# Epoch no. 15 |accuracy:  5.732 % |total_loss:  42.408994050565525
# Epoch no. 15 |accuracy:  5.752 % |total_loss:  42.41321293251531
# Epoch no. 15 |accuracy:  5.772 % |total_loss:  42.548721186685725
# Epoch no. 15 |accuracy:  5.792 % |total_loss:  42.61475045220868
# Epoch no. 15 |accuracy:  5.812 % |total_loss:  42.655696105081006
# Epoch no. 15 |accuracy:  5.832 % |total_loss:  42.72938190760033
# Epoch no. 15 |accuracy:  5.848 % |total_loss:  43.13773887218849
# Epoch no. 15 |accuracy:  5.866 % |total_loss:  43.26408899189846
# Epoch no. 15 |accuracy:  5.884 % |total_loss:  43.50414252640621
# Epoch no. 15 |accuracy:  5.904 % |total_loss:  43.55445790650265
# Epoch no. 15 |accuracy:  5.924 % |total_loss:  43.57053073668794
# Epoch no. 15 |accuracy:  5.942 % |total_loss:  43.64306260073499
# Epoch no. 15 |accuracy:  5.96 % |total_loss:  43.7486021163495
# Epoch no. 15 |accuracy:  5.98 % |total_loss:  43.761942330616876
# Epoch no. 15 |accuracy:  6.0 % |total_loss:  43.76389392207784
# Epoch no. 15 |accuracy:  6.012 % |total_loss:  44.72588511298818
# Epoch no. 15 |accuracy:  6.032 % |total_loss:  44.76383360962791
# Epoch no. 15 |accuracy:  6.05 % |total_loss:  44.999706742572016
# Epoch no. 15 |accuracy:  6.068 % |total_loss:  45.142632705377764
# Epoch no. 15 |accuracy:  6.088 % |total_loss:  45.258899432825274
# Epoch no. 15 |accuracy:  6.106 % |total_loss:  45.39455307762546
# Epoch no. 15 |accuracy:  6.126 % |total_loss:  45.417648460002965
# Epoch no. 15 |accuracy:  6.146 % |total_loss:  45.436386949601
# Epoch no. 15 |accuracy:  6.164 % |total_loss:  45.690257168593234
# Epoch no. 15 |accuracy:  6.18 % |total_loss:  46.11975935775263
# Epoch no. 15 |accuracy:  6.198 % |total_loss:  46.36609340387804
# Epoch no. 15 |accuracy:  6.214 % |total_loss:  46.60116625505907
# Epoch no. 15 |accuracy:  6.234 % |total_loss:  46.69685073870642
# Epoch no. 15 |accuracy:  6.252 % |total_loss:  46.898512250962085
# Epoch no. 15 |accuracy:  6.272 % |total_loss:  46.985762438955135
# Epoch no. 15 |accuracy:  6.292 % |total_loss:  46.998501766691334
# Epoch no. 15 |accuracy:  6.31 % |total_loss:  47.21290959812177
# Epoch no. 15 |accuracy:  6.33 % |total_loss:  47.229219410786754
# Epoch no. 15 |accuracy:  6.35 % |total_loss:  47.25162224120868
# Epoch no. 15 |accuracy:  6.368 % |total_loss:  47.37696984059585
# Epoch no. 15 |accuracy:  6.388 % |total_loss:  47.52769147999061
# Epoch no. 15 |accuracy:  6.404 % |total_loss:  47.926064666578895
# Epoch no. 15 |accuracy:  6.424 % |total_loss:  47.93495469841582
# Epoch no. 15 |accuracy:  6.444 % |total_loss:  48.05863976034743
# Epoch no. 15 |accuracy:  6.464 % |total_loss:  48.12490408423764
# Epoch no. 15 |accuracy:  6.482 % |total_loss:  48.55547811392171
# Epoch no. 15 |accuracy:  6.502 % |total_loss:  48.55932977491466
# Epoch no. 15 |accuracy:  6.52 % |total_loss:  48.66875645214168
# Epoch no. 15 |accuracy:  6.54 % |total_loss:  48.67880415984837
# Epoch no. 15 |accuracy:  6.56 % |total_loss:  48.70528561504034
# Epoch no. 15 |accuracy:  6.578 % |total_loss:  49.287149316383875
# Epoch no. 15 |accuracy:  6.594 % |total_loss:  49.48810499043611
# Epoch no. 15 |accuracy:  6.614 % |total_loss:  49.500642628161586
# Epoch no. 15 |accuracy:  6.634 % |total_loss:  49.59908187457768
# Epoch no. 15 |accuracy:  6.654 % |total_loss:  49.63301097670046
# Epoch no. 15 |accuracy:  6.674 % |total_loss:  49.63942202854378
# Epoch no. 15 |accuracy:  6.694 % |total_loss:  49.643924985299236
# Epoch no. 15 |accuracy:  6.714 % |total_loss:  49.64552462681604
# Epoch no. 15 |accuracy:  6.734 % |total_loss:  49.70479422643257
# Epoch no. 15 |accuracy:  6.748 % |total_loss:  50.49942582681251
# Epoch no. 15 |accuracy:  6.768 % |total_loss:  50.505523393148906
# Epoch no. 15 |accuracy:  6.788 % |total_loss:  50.52850825547648
# Epoch no. 15 |accuracy:  6.806 % |total_loss:  50.62950115858985
# Epoch no. 15 |accuracy:  6.826 % |total_loss:  50.68616579681111
# Epoch no. 15 |accuracy:  6.846 % |total_loss:  50.71812350511027
# Epoch no. 15 |accuracy:  6.866 % |total_loss:  50.77521471887303
# Epoch no. 15 |accuracy:  6.886 % |total_loss:  50.78029696991143
# Epoch no. 15 |accuracy:  6.906 % |total_loss:  50.858626212677336
# Epoch no. 15 |accuracy:  6.924 % |total_loss:  51.12962370713649
# Epoch no. 15 |accuracy:  6.944 % |total_loss:  51.131985664818785
# Epoch no. 15 |accuracy:  6.964 % |total_loss:  51.170679215792916
# Epoch no. 15 |accuracy:  6.984 % |total_loss:  51.20783911317994
# Epoch no. 15 |accuracy:  7.002 % |total_loss:  51.28508402824809
# Epoch no. 15 |accuracy:  7.02 % |total_loss:  51.492357705239556
# Epoch no. 15 |accuracy:  7.036 % |total_loss:  51.833630476598046
# Epoch no. 15 |accuracy:  7.054 % |total_loss:  51.9348963615339
# Epoch no. 15 |accuracy:  7.074 % |total_loss:  51.982523285303614
# Epoch no. 15 |accuracy:  7.094 % |total_loss:  52.00671907931974
# Epoch no. 15 |accuracy:  7.112 % |total_loss:  52.304754611555836
# Epoch no. 15 |accuracy:  7.132 % |total_loss:  52.491714027230046
# Epoch no. 15 |accuracy:  7.152 % |total_loss:  52.61913311154058
# Epoch no. 15 |accuracy:  7.172 % |total_loss:  52.66458769187739
# Epoch no. 15 |accuracy:  7.19 % |total_loss:  52.87867151245882
# Epoch no. 15 |accuracy:  7.21 % |total_loss:  52.95308240548184
# Epoch no. 15 |accuracy:  7.228 % |total_loss:  53.09821604982426
# Epoch no. 15 |accuracy:  7.246 % |total_loss:  53.26920913950016
# Epoch no. 15 |accuracy:  7.266 % |total_loss:  53.30096832707932
# Epoch no. 15 |accuracy:  7.286 % |total_loss:  53.403944947276614
# Epoch no. 15 |accuracy:  7.306 % |total_loss:  53.52763795152714
# Epoch no. 15 |accuracy:  7.326 % |total_loss:  53.55175517544558
# Epoch no. 15 |accuracy:  7.346 % |total_loss:  53.574512439299724
# Epoch no. 15 |accuracy:  7.366 % |total_loss:  53.59330220006814
# Epoch no. 15 |accuracy:  7.382 % |total_loss:  53.85058710955491
# Epoch no. 15 |accuracy:  7.4 % |total_loss:  54.09591991685738
# Epoch no. 15 |accuracy:  7.418 % |total_loss:  54.354658941258094
# Epoch no. 15 |accuracy:  7.436 % |total_loss:  54.46111303799262
# Epoch no. 15 |accuracy:  7.454 % |total_loss:  54.58951252930274
# Epoch no. 15 |accuracy:  7.474 % |total_loss:  54.62872571729531
# Epoch no. 15 |accuracy:  7.494 % |total_loss:  54.63385209951957
# Epoch no. 15 |accuracy:  7.514 % |total_loss:  54.668570277732215
# Epoch no. 15 |accuracy:  7.534 % |total_loss:  54.711154343080125
# Epoch no. 15 |accuracy:  7.554 % |total_loss:  54.7719849957939
# Epoch no. 15 |accuracy:  7.572 % |total_loss:  54.93982555110415
# Epoch no. 15 |accuracy:  7.592 % |total_loss:  55.012060293447576
# Epoch no. 15 |accuracy:  7.612 % |total_loss:  55.026573162977
# Epoch no. 15 |accuracy:  7.63 % |total_loss:  55.13782876402547
# Epoch no. 15 |accuracy:  7.646 % |total_loss:  55.53374167949369
# Epoch no. 15 |accuracy:  7.666 % |total_loss:  55.55941677883675
# Epoch no. 15 |accuracy:  7.686 % |total_loss:  55.61129577503016
# Epoch no. 15 |accuracy:  7.706 % |total_loss:  55.660849545602105
# Epoch no. 15 |accuracy:  7.724 % |total_loss:  55.858045284156105
# Epoch no. 15 |accuracy:  7.742 % |total_loss:  56.20526457250526
# Epoch no. 15 |accuracy:  7.762 % |total_loss:  56.27219348818471
# Epoch no. 15 |accuracy:  7.782 % |total_loss:  56.42194893628766
# Epoch no. 15 |accuracy:  7.802 % |total_loss:  56.44896209843864
# Epoch no. 15 |accuracy:  7.822 % |total_loss:  56.44994822888111
# Epoch no. 15 |accuracy:  7.84 % |total_loss:  56.85570804028248
# Epoch no. 15 |accuracy:  7.86 % |total_loss:  56.86039336443355
# Epoch no. 15 |accuracy:  7.876 % |total_loss:  57.30219842911174
# Epoch no. 15 |accuracy:  7.892 % |total_loss:  58.01370419979503
# Epoch no. 15 |accuracy:  7.91 % |total_loss:  58.25232860863616
# Epoch no. 15 |accuracy:  7.93 % |total_loss:  58.27658096559753
# Epoch no. 15 |accuracy:  7.95 % |total_loss:  58.39668430991878
# Epoch no. 15 |accuracy:  7.97 % |total_loss:  58.46077046402206
# Epoch no. 15 |accuracy:  7.99 % |total_loss:  58.56187315144052
# Epoch no. 15 |accuracy:  8.01 % |total_loss:  58.58961357966473
# Epoch no. 15 |accuracy:  8.022 % |total_loss:  59.25583567515423
# Epoch no. 15 |accuracy:  8.042 % |total_loss:  59.29733596042206
# Epoch no. 15 |accuracy:  8.06 % |total_loss:  59.569327511344454
# Epoch no. 15 |accuracy:  8.078 % |total_loss:  59.97878909901192
# Epoch no. 15 |accuracy:  8.098 % |total_loss:  60.025927786235115
# Epoch no. 15 |accuracy:  8.118 % |total_loss:  60.04810835838725
# Epoch no. 15 |accuracy:  8.138 % |total_loss:  60.112015668753884
# Epoch no. 15 |accuracy:  8.152 % |total_loss:  60.77421814620902
# Epoch no. 15 |accuracy:  8.17 % |total_loss:  60.98729187667777
# Epoch no. 15 |accuracy:  8.19 % |total_loss:  61.00674488626828
# Epoch no. 15 |accuracy:  8.206 % |total_loss:  61.360484982360504
# Epoch no. 15 |accuracy:  8.224 % |total_loss:  61.64621096335759
# Epoch no. 15 |accuracy:  8.244 % |total_loss:  61.67223402716627
# Epoch no. 15 |accuracy:  8.264 % |total_loss:  61.6815742575418
# Epoch no. 15 |accuracy:  8.284 % |total_loss:  61.69523255013337
# Epoch no. 15 |accuracy:  8.302 % |total_loss:  61.832700634826324
# Epoch no. 15 |accuracy:  8.322 % |total_loss:  61.88300731264462
# Epoch no. 15 |accuracy:  8.342 % |total_loss:  61.94262841575255
# Epoch no. 15 |accuracy:  8.362 % |total_loss:  61.967605194528005
# Epoch no. 15 |accuracy:  8.382 % |total_loss:  62.04976196445932
# Epoch no. 15 |accuracy:  8.4 % |total_loss:  62.247828824896715
# Epoch no. 15 |accuracy:  8.42 % |total_loss:  62.33356643326988
# Epoch no. 15 |accuracy:  8.44 % |total_loss:  62.449000588138006
# Epoch no. 15 |accuracy:  8.458 % |total_loss:  62.97995393582096
# Epoch no. 15 |accuracy:  8.478 % |total_loss:  62.981060729929595
# Epoch no. 15 |accuracy:  8.496 % |total_loss:  63.24460186214128
# Epoch no. 15 |accuracy:  8.51 % |total_loss:  64.06332124919572
# Epoch no. 15 |accuracy:  8.528 % |total_loss:  64.14843199551979
# Epoch no. 15 |accuracy:  8.548 % |total_loss:  64.14936579587811
# Epoch no. 15 |accuracy:  8.566 % |total_loss:  64.32496820214146
# Epoch no. 15 |accuracy:  8.584 % |total_loss:  64.62568364861363
# Epoch no. 15 |accuracy:  8.6 % |total_loss:  65.13761351826543
# Epoch no. 15 |accuracy:  8.62 % |total_loss:  65.21053674641007
# Epoch no. 15 |accuracy:  8.638 % |total_loss:  65.39291179004067
# Epoch no. 15 |accuracy:  8.658 % |total_loss:  65.48538303199166
# Epoch no. 15 |accuracy:  8.678 % |total_loss:  65.56743436875695
# Epoch no. 15 |accuracy:  8.698 % |total_loss:  65.65721650245541
# Epoch no. 15 |accuracy:  8.716 % |total_loss:  65.86149540367478
# Epoch no. 15 |accuracy:  8.736 % |total_loss:  65.9102820512926
# Epoch no. 15 |accuracy:  8.756 % |total_loss:  65.93185237991565
# Epoch no. 15 |accuracy:  8.776 % |total_loss:  65.99633058356994
# Epoch no. 15 |accuracy:  8.792 % |total_loss:  66.29591229009384
# Epoch no. 15 |accuracy:  8.812 % |total_loss:  66.32120761099213
# Epoch no. 15 |accuracy:  8.83 % |total_loss:  66.67900964441651
# Epoch no. 15 |accuracy:  8.848 % |total_loss:  66.93610569658631
# Epoch no. 15 |accuracy:  8.866 % |total_loss:  67.06352892341965
# Epoch no. 15 |accuracy:  8.884 % |total_loss:  67.37187680425995
# Epoch no. 15 |accuracy:  8.904 % |total_loss:  67.38077429412806
# Epoch no. 15 |accuracy:  8.924 % |total_loss:  67.39429236399883
# Epoch no. 15 |accuracy:  8.942 % |total_loss:  67.55440665232891
# Epoch no. 15 |accuracy:  8.962 % |total_loss:  67.60022697049135
# Epoch no. 15 |accuracy:  8.982 % |total_loss:  67.77260002690309
# Epoch no. 15 |accuracy:  9.0 % |total_loss:  68.0178565998649
# Epoch no. 15 |accuracy:  9.02 % |total_loss:  68.13708702671283
# Epoch no. 15 |accuracy:  9.04 % |total_loss:  68.16758649061376
# Epoch no. 15 |accuracy:  9.058 % |total_loss:  68.26870232830697
# Epoch no. 15 |accuracy:  9.076 % |total_loss:  68.37455651919299
# Epoch no. 15 |accuracy:  9.096 % |total_loss:  68.4427619130438
# Epoch no. 15 |accuracy:  9.116 % |total_loss:  68.44672537465522
# Epoch no. 15 |accuracy:  9.132 % |total_loss:  68.75039539356658
# Epoch no. 15 |accuracy:  9.148 % |total_loss:  69.19386545439193
# Epoch no. 15 |accuracy:  9.168 % |total_loss:  69.305146394865
# Epoch no. 15 |accuracy:  9.188 % |total_loss:  69.3286943925632
# Epoch no. 15 |accuracy:  9.208 % |total_loss:  69.38897185456881
# Epoch no. 15 |accuracy:  9.224 % |total_loss:  69.8711491717113
# Epoch no. 15 |accuracy:  9.242 % |total_loss:  70.1308517051948
# Epoch no. 15 |accuracy:  9.262 % |total_loss:  70.19855884146818
# Epoch no. 15 |accuracy:  9.282 % |total_loss:  70.35575230848917
# Epoch no. 15 |accuracy:  9.302 % |total_loss:  70.40813434180745
# Epoch no. 15 |accuracy:  9.322 % |total_loss:  70.4179894305853
# Epoch no. 15 |accuracy:  9.34 % |total_loss:  70.6369318045763
# Epoch no. 15 |accuracy:  9.36 % |total_loss:  70.64263998401293
# Epoch no. 15 |accuracy:  9.374 % |total_loss:  71.1757886303676
# Epoch no. 15 |accuracy:  9.394 % |total_loss:  71.2187161823822
# Epoch no. 15 |accuracy:  9.414 % |total_loss:  71.26983110663423
# Epoch no. 15 |accuracy:  9.432 % |total_loss:  71.35217714366445
# Epoch no. 15 |accuracy:  9.452 % |total_loss:  71.35700487122813
# Epoch no. 15 |accuracy:  9.47 % |total_loss:  71.67667611465731
# Epoch no. 15 |accuracy:  9.484 % |total_loss:  72.02986299023905
# Epoch no. 15 |accuracy:  9.504 % |total_loss:  72.05500996076444
# Epoch no. 15 |accuracy:  9.518 % |total_loss:  73.2491649385629
# Epoch no. 15 |accuracy:  9.538 % |total_loss:  73.25373960017168
# Epoch no. 15 |accuracy:  9.556 % |total_loss:  73.39993875204527
# Epoch no. 15 |accuracy:  9.576 % |total_loss:  73.49448516695702
# Epoch no. 15 |accuracy:  9.596 % |total_loss:  73.5394815030595
# Epoch no. 15 |accuracy:  9.616 % |total_loss:  73.54135729731934
# Epoch no. 15 |accuracy:  9.634 % |total_loss:  73.67869107784645
# Epoch no. 15 |accuracy:  9.654 % |total_loss:  73.77789409073011
# Epoch no. 15 |accuracy:  9.672 % |total_loss:  73.93232945712225
# Epoch no. 15 |accuracy:  9.692 % |total_loss:  73.93718616371916
# Epoch no. 15 |accuracy:  9.712 % |total_loss:  74.00714127426909
# Epoch no. 15 |accuracy:  9.73 % |total_loss:  74.14062915449904
# Epoch no. 15 |accuracy:  9.75 % |total_loss:  74.22250026917027
# Epoch no. 15 |accuracy:  9.77 % |total_loss:  74.2249499711761
# Epoch no. 15 |accuracy:  9.786 % |total_loss:  74.94704879853816
# Epoch no. 15 |accuracy:  9.806 % |total_loss:  74.9819431122014
# Epoch no. 15 |accuracy:  9.824 % |total_loss:  75.08029944110604
# Epoch no. 15 |accuracy:  9.844 % |total_loss:  75.08079375232046
# Epoch no. 15 |accuracy:  9.862 % |total_loss:  75.2418371578533
# Epoch no. 15 |accuracy:  9.882 % |total_loss:  75.3745616068918
# Epoch no. 15 |accuracy:  9.9 % |total_loss:  75.67460694814508
# Epoch no. 15 |accuracy:  9.92 % |total_loss:  75.80880698467081
# Epoch no. 15 |accuracy:  9.94 % |total_loss:  75.81306417424639
# Epoch no. 15 |accuracy:  9.96 % |total_loss:  75.86014744032582
# Epoch no. 15 |accuracy:  9.978 % |total_loss:  75.95333731312712
# Epoch no. 15 |accuracy:  9.992 % |total_loss:  77.05963313717803
# Epoch no. 15 |accuracy:  10.01 % |total_loss:  77.403750778627
# Epoch no. 15 |accuracy:  10.028 % |total_loss:  77.6624069823738
# Epoch no. 15 |accuracy:  10.048 % |total_loss:  77.6985948174115
# Epoch no. 15 |accuracy:  10.066 % |total_loss:  77.83170501280983
# Epoch no. 15 |accuracy:  10.084 % |total_loss:  77.96212280679902
# Epoch no. 15 |accuracy:  10.102 % |total_loss:  78.11189887810906
# Epoch no. 15 |accuracy:  10.12 % |total_loss:  78.27332288910111
# Epoch no. 15 |accuracy:  10.14 % |total_loss:  78.3361961706396
# Epoch no. 15 |accuracy:  10.158 % |total_loss:  78.42636629332264
# Epoch no. 15 |accuracy:  10.178 % |total_loss:  78.58374253798684
# Epoch no. 15 |accuracy:  10.196 % |total_loss:  78.66117649663647
# Epoch no. 15 |accuracy:  10.216 % |total_loss:  78.69202380393108
# Epoch no. 15 |accuracy:  10.234 % |total_loss:  78.94305645440181
# Epoch no. 15 |accuracy:  10.254 % |total_loss:  78.97930639747938
# Epoch no. 15 |accuracy:  10.27 % |total_loss:  79.2355614281114
# Epoch no. 15 |accuracy:  10.29 % |total_loss:  79.24998382244667
# Epoch no. 15 |accuracy:  10.308 % |total_loss:  79.59467372809013
# Epoch no. 15 |accuracy:  10.328 % |total_loss:  79.62794934351405
# Epoch no. 15 |accuracy:  10.346 % |total_loss:  79.98967285592516
# Epoch no. 15 |accuracy:  10.366 % |total_loss:  80.01444747623464
# Epoch no. 15 |accuracy:  10.384 % |total_loss:  80.2983654099371
# Epoch no. 15 |accuracy:  10.404 % |total_loss:  80.31809065070411
# Epoch no. 15 |accuracy:  10.424 % |total_loss:  80.40992048707267
# Epoch no. 15 |accuracy:  10.444 % |total_loss:  80.439082033452
# Epoch no. 15 |accuracy:  10.462 % |total_loss:  80.6027750591602
# Epoch no. 15 |accuracy:  10.482 % |total_loss:  80.68259004455467
# Epoch no. 15 |accuracy:  10.5 % |total_loss:  80.87871188622375
# Epoch no. 15 |accuracy:  10.518 % |total_loss:  81.15408597093483
# Epoch no. 15 |accuracy:  10.538 % |total_loss:  81.15445613100019
# Epoch no. 15 |accuracy:  10.558 % |total_loss:  81.21359200759616
# Epoch no. 15 |accuracy:  10.578 % |total_loss:  81.21429313767294
# Epoch no. 15 |accuracy:  10.598 % |total_loss:  81.25244835812191
# Epoch no. 15 |accuracy:  10.618 % |total_loss:  81.38891994256119
# Epoch no. 15 |accuracy:  10.638 % |total_loss:  81.41546594399551
# Epoch no. 15 |accuracy:  10.656 % |total_loss:  81.7627510358725
# Epoch no. 15 |accuracy:  10.676 % |total_loss:  81.83470603126625
# Epoch no. 15 |accuracy:  10.692 % |total_loss:  82.14183648723701
# Epoch no. 15 |accuracy:  10.71 % |total_loss:  82.25628723997215
# Epoch no. 15 |accuracy:  10.73 % |total_loss:  82.31346833008865
# Epoch no. 15 |accuracy:  10.748 % |total_loss:  82.41402615654806
# Epoch no. 15 |accuracy:  10.766 % |total_loss:  82.83340187418798
# Epoch no. 15 |accuracy:  10.786 % |total_loss:  82.85322914879362
# Epoch no. 15 |accuracy:  10.804 % |total_loss:  83.0459012673382
# Epoch no. 15 |accuracy:  10.82 % |total_loss:  83.40183055262605
# Epoch no. 15 |accuracy:  10.84 % |total_loss:  83.42095846730808
# Epoch no. 15 |accuracy:  10.86 % |total_loss:  83.45398770693282
# Epoch no. 15 |accuracy:  10.878 % |total_loss:  84.13359217766265
# Epoch no. 15 |accuracy:  10.898 % |total_loss:  84.13464163675962
# Epoch no. 15 |accuracy:  10.918 % |total_loss:  84.24939811661898
# Epoch no. 15 |accuracy:  10.936 % |total_loss:  84.3970044596499
# Epoch no. 15 |accuracy:  10.956 % |total_loss:  84.49744921609818
# Epoch no. 15 |accuracy:  10.976 % |total_loss:  84.61422250106989
# Epoch no. 15 |accuracy:  10.996 % |total_loss:  84.63993463352381
# Epoch no. 15 |accuracy:  11.016 % |total_loss:  84.6735115727788
# Epoch no. 15 |accuracy:  11.034 % |total_loss:  84.84078686744033
# Epoch no. 15 |accuracy:  11.052 % |total_loss:  85.19955243974982
# Epoch no. 15 |accuracy:  11.07 % |total_loss:  85.46435316711722
# Epoch no. 15 |accuracy:  11.088 % |total_loss:  85.70297015518008
# Epoch no. 15 |accuracy:  11.108 % |total_loss:  85.9170775195962
# Epoch no. 15 |accuracy:  11.126 % |total_loss:  86.122072704733
# Epoch no. 15 |accuracy:  11.144 % |total_loss:  86.24279999047576
# Epoch no. 15 |accuracy:  11.164 % |total_loss:  86.24691741786955
# Epoch no. 15 |accuracy:  11.182 % |total_loss:  86.47038099788188
# Epoch no. 15 |accuracy:  11.198 % |total_loss:  87.01888320468424
# Epoch no. 15 |accuracy:  11.218 % |total_loss:  87.02835797205626
# Epoch no. 15 |accuracy:  11.238 % |total_loss:  87.04340852204768
# Epoch no. 15 |accuracy:  11.256 % |total_loss:  87.2568293899676
# Epoch no. 15 |accuracy:  11.276 % |total_loss:  87.30888122100441
# Epoch no. 15 |accuracy:  11.296 % |total_loss:  87.31125011471158
# Epoch no. 15 |accuracy:  11.316 % |total_loss:  87.33413666104025
# Epoch no. 15 |accuracy:  11.334 % |total_loss:  87.44870261465257
# Epoch no. 15 |accuracy:  11.352 % |total_loss:  87.74633507047838
# Epoch no. 15 |accuracy:  11.37 % |total_loss:  88.11676261936373
# Epoch no. 15 |accuracy:  11.388 % |total_loss:  88.2406322396273
# Epoch no. 15 |accuracy:  11.406 % |total_loss:  88.41187355284637
# Epoch no. 15 |accuracy:  11.426 % |total_loss:  88.49340902631229
# Epoch no. 15 |accuracy:  11.446 % |total_loss:  88.54488545646018
# Epoch no. 15 |accuracy:  11.464 % |total_loss:  88.67986662675685
# Epoch no. 15 |accuracy:  11.482 % |total_loss:  88.8256247042591
# Epoch no. 15 |accuracy:  11.502 % |total_loss:  88.83749209892994
# Epoch no. 15 |accuracy:  11.52 % |total_loss:  89.05005330395943
# Epoch no. 15 |accuracy:  11.536 % |total_loss:  89.70414597344643
# Epoch no. 15 |accuracy:  11.552 % |total_loss:  90.01236004185921
# Epoch no. 15 |accuracy:  11.566 % |total_loss:  90.63486326289421
# Epoch no. 15 |accuracy:  11.586 % |total_loss:  90.7628425265575
# Epoch no. 15 |accuracy:  11.606 % |total_loss:  90.79928920966631
# Epoch no. 15 |accuracy:  11.626 % |total_loss:  90.9004041383887
# Epoch no. 15 |accuracy:  11.644 % |total_loss:  91.06482161385065
# Epoch no. 15 |accuracy:  11.662 % |total_loss:  91.2675875256682
# Epoch no. 15 |accuracy:  11.68 % |total_loss:  91.35676269781834
# Epoch no. 15 |accuracy:  11.698 % |total_loss:  91.61738764298207
# Epoch no. 15 |accuracy:  11.718 % |total_loss:  91.64577652690059
# Epoch no. 15 |accuracy:  11.738 % |total_loss:  91.78009516176826
# Epoch no. 15 |accuracy:  11.756 % |total_loss:  91.90244369384891
# Epoch no. 15 |accuracy:  11.772 % |total_loss:  92.2269478308881
# Epoch no. 15 |accuracy:  11.792 % |total_loss:  92.33099126991874
# Epoch no. 15 |accuracy:  11.808 % |total_loss:  92.75983357605583
# Epoch no. 15 |accuracy:  11.826 % |total_loss:  92.86337138888484
# Epoch no. 15 |accuracy:  11.844 % |total_loss:  93.02506293532497
# Epoch no. 15 |accuracy:  11.864 % |total_loss:  93.04755046394712
# Epoch no. 15 |accuracy:  11.882 % |total_loss:  93.22006938782579
# Epoch no. 15 |accuracy:  11.902 % |total_loss:  93.22840705969429
# Epoch no. 15 |accuracy:  11.922 % |total_loss:  93.23290718057251
# Epoch no. 15 |accuracy:  11.942 % |total_loss:  93.27879725479579
# Epoch no. 15 |accuracy:  11.96 % |total_loss:  93.51377947711444
# Epoch no. 15 |accuracy:  11.974 % |total_loss:  93.89523141169047
# Epoch no. 15 |accuracy:  11.994 % |total_loss:  94.01103075676656
# Epoch no. 15 |accuracy:  12.01 % |total_loss:  94.24795235031343
# Epoch no. 15 |accuracy:  12.03 % |total_loss:  94.26723599889374
# Epoch no. 15 |accuracy:  12.048 % |total_loss:  94.5030235991726
# Epoch no. 15 |accuracy:  12.066 % |total_loss:  94.77407089331246
# Epoch no. 15 |accuracy:  12.086 % |total_loss:  94.78045921762532
# Epoch no. 15 |accuracy:  12.106 % |total_loss:  94.89654055972642
# Epoch no. 15 |accuracy:  12.126 % |total_loss:  94.90959537298477
# Epoch no. 15 |accuracy:  12.146 % |total_loss:  94.92565001630282
# Epoch no. 15 |accuracy:  12.164 % |total_loss:  95.06189517759776
# Epoch no. 15 |accuracy:  12.182 % |total_loss:  95.2501116850326
# Epoch no. 15 |accuracy:  12.2 % |total_loss:  95.44459945046401
# Epoch no. 15 |accuracy:  12.218 % |total_loss:  95.6926978238771
# Epoch no. 15 |accuracy:  12.236 % |total_loss:  96.00495165669417
# Epoch no. 15 |accuracy:  12.256 % |total_loss:  96.01265149041137
# Epoch no. 15 |accuracy:  12.274 % |total_loss:  96.29111944361648
# Epoch no. 15 |accuracy:  12.294 % |total_loss:  96.35742882116756
# Epoch no. 15 |accuracy:  12.31 % |total_loss:  96.68744778855762
# Epoch no. 15 |accuracy:  12.33 % |total_loss:  96.78884446843585
# Epoch no. 15 |accuracy:  12.35 % |total_loss:  96.86643467321119
# Epoch no. 15 |accuracy:  12.37 % |total_loss:  96.90059939249477
# Epoch no. 15 |accuracy:  12.388 % |total_loss:  97.18456074818096
# Epoch no. 15 |accuracy:  12.406 % |total_loss:  97.29123331083974
# Epoch no. 15 |accuracy:  12.424 % |total_loss:  97.82062686457357
# Epoch no. 15 |accuracy:  12.444 % |total_loss:  97.88705351426324
# Epoch no. 15 |accuracy:  12.464 % |total_loss:  97.91150370090327
# Epoch no. 15 |accuracy:  12.48 % |total_loss:  98.44062152355036
# Epoch no. 15 |accuracy:  12.496 % |total_loss:  99.00619187801203
# Epoch no. 15 |accuracy:  12.516 % |total_loss:  99.03324274941406
# Epoch no. 15 |accuracy:  12.536 % |total_loss:  99.03671735445096
# Epoch no. 15 |accuracy:  12.556 % |total_loss:  99.15423740366532
# Epoch no. 15 |accuracy:  12.574 % |total_loss:  99.2937574825628
# Epoch no. 15 |accuracy:  12.592 % |total_loss:  99.57922418335511
# Epoch no. 15 |accuracy:  12.61 % |total_loss:  99.78666675010754
# Epoch no. 15 |accuracy:  12.628 % |total_loss:  100.02510964790417
# Epoch no. 15 |accuracy:  12.648 % |total_loss:  100.06713689783646
# Epoch no. 15 |accuracy:  12.666 % |total_loss:  100.34274585465027
# Epoch no. 15 |accuracy:  12.686 % |total_loss:  100.35663895042671
# Epoch no. 15 |accuracy:  12.702 % |total_loss:  100.66390000017418
# Epoch no. 15 |accuracy:  12.72 % |total_loss:  101.0061093095137
# Epoch no. 15 |accuracy:  12.738 % |total_loss:  101.41735790403618
# Epoch no. 15 |accuracy:  12.754 % |total_loss:  101.79745621712937
# Epoch no. 15 |accuracy:  12.77 % |total_loss:  102.47429294617905
# Epoch no. 15 |accuracy:  12.788 % |total_loss:  102.6901818934275
# Epoch no. 15 |accuracy:  12.808 % |total_loss:  102.72656731413736
# Epoch no. 15 |accuracy:  12.826 % |total_loss:  102.8832066218747
# Epoch no. 15 |accuracy:  12.846 % |total_loss:  102.94882810222043
# Epoch no. 15 |accuracy:  12.866 % |total_loss:  103.03603437649144
# Epoch no. 15 |accuracy:  12.884 % |total_loss:  103.22684568272962
# Epoch no. 15 |accuracy:  12.902 % |total_loss:  103.32922849910392
# Epoch no. 15 |accuracy:  12.922 % |total_loss:  103.47580128269328
# Epoch no. 15 |accuracy:  12.938 % |total_loss:  103.76287435846461
# Epoch no. 15 |accuracy:  12.958 % |total_loss:  103.85859955208434
# Epoch no. 15 |accuracy:  12.976 % |total_loss:  104.1491353596939
# Epoch no. 15 |accuracy:  12.996 % |total_loss:  104.19817400084867
# Epoch no. 15 |accuracy:  13.016 % |total_loss:  104.24963954197301
# Epoch no. 15 |accuracy:  13.036 % |total_loss:  104.27571301268472
# Epoch no. 15 |accuracy:  13.054 % |total_loss:  104.41695563601388
# Epoch no. 15 |accuracy:  13.074 % |total_loss:  104.5690193335904
# Epoch no. 15 |accuracy:  13.094 % |total_loss:  104.64428554581536
# Epoch no. 15 |accuracy:  13.114 % |total_loss:  104.66421425821318
# Epoch no. 15 |accuracy:  13.132 % |total_loss:  105.01465291263594
# Epoch no. 15 |accuracy:  13.152 % |total_loss:  105.09086875351204
# Epoch no. 15 |accuracy:  13.168 % |total_loss:  105.46200369032158
# Epoch no. 15 |accuracy:  13.186 % |total_loss:  105.64775113495125
# Epoch no. 15 |accuracy:  13.204 % |total_loss:  105.86371692748799
# Epoch no. 15 |accuracy:  13.222 % |total_loss:  105.97895495327248
# Epoch no. 15 |accuracy:  13.242 % |total_loss:  105.99534610020055
# Epoch no. 15 |accuracy:  13.262 % |total_loss:  106.03366407858266
# Epoch no. 15 |accuracy:  13.282 % |total_loss:  106.05845056207909
# Epoch no. 15 |accuracy:  13.302 % |total_loss:  106.13190167876019
# Epoch no. 15 |accuracy:  13.32 % |total_loss:  106.30143362017407
# Epoch no. 15 |accuracy:  13.336 % |total_loss:  107.07980555029644
# Epoch no. 15 |accuracy:  13.354 % |total_loss:  107.20996345313324
# Epoch no. 15 |accuracy:  13.374 % |total_loss:  107.24681054534449
# Epoch no. 15 |accuracy:  13.394 % |total_loss:  107.33047852398886
# Epoch no. 15 |accuracy:  13.41 % |total_loss:  107.82824644925131
# Epoch no. 15 |accuracy:  13.426 % |total_loss:  108.04531758012308
# Epoch no. 15 |accuracy:  13.446 % |total_loss:  108.07344251418544
# Epoch no. 15 |accuracy:  13.46 % |total_loss:  108.61282598519756
# Epoch no. 15 |accuracy:  13.48 % |total_loss:  108.71706509137584
# Epoch no. 15 |accuracy:  13.5 % |total_loss:  108.7455760549201
# Epoch no. 15 |accuracy:  13.518 % |total_loss:  109.07999429212941
# Epoch no. 15 |accuracy:  13.536 % |total_loss:  109.25788408624067
# Epoch no. 15 |accuracy:  13.556 % |total_loss:  109.26079546044639
# Epoch no. 15 |accuracy:  13.576 % |total_loss:  109.3617567432957
# Epoch no. 15 |accuracy:  13.594 % |total_loss:  109.59769286344817
# Epoch no. 15 |accuracy:  13.614 % |total_loss:  109.65448219086102
# Epoch no. 15 |accuracy:  13.634 % |total_loss:  109.69659937675169
# Epoch no. 15 |accuracy:  13.654 % |total_loss:  109.74597017969063
# Epoch no. 15 |accuracy:  13.674 % |total_loss:  109.77774672712258
# Epoch no. 15 |accuracy:  13.692 % |total_loss:  109.89865942056349
# ...
# Epoch no. 15 |accuracy:  88.714 % |total_loss:  859.6109910304222
# Epoch no. 15 |accuracy:  88.734 % |total_loss:  859.7059954697761
# Epoch no. 15 |accuracy:  88.752 % |total_loss:  859.9127598846826
# Epoch no. 15 |accuracy:  88.77 % |total_loss:  860.1163761759672
# Epoch no. 15 |accuracy:  88.79 % |total_loss:  860.151440247384
# Epoch no. 15 |accuracy:  88.802 % |total_loss:  860.701708897439
# Epoch no. 15 |accuracy:  88.822 % |total_loss:  860.7137265693891
# Epoch no. 15 |accuracy:  88.838 % |total_loss:  861.43120538113
# Epoch no. 15 |accuracy:  88.858 % |total_loss:  861.4473115694273
# Epoch no. 15 |accuracy:  88.878 % |total_loss:  861.5965613019216
# Epoch no. 15 |accuracy:  88.892 % |total_loss:  863.3061796319234
# Epoch no. 15 |accuracy:  88.91 % |total_loss:  863.6165860783804
# Epoch no. 15 |accuracy:  88.926 % |total_loss:  863.9507549297559
# Epoch no. 15 |accuracy:  88.946 % |total_loss:  863.9775767907995
# Epoch no. 15 |accuracy:  88.966 % |total_loss:  863.9822203903022
# Epoch no. 15 |accuracy:  88.982 % |total_loss:  864.2274314700189
# Epoch no. 15 |accuracy:  89.0 % |total_loss:  864.3789550005022
# Epoch no. 15 |accuracy:  89.018 % |total_loss:  864.6789035736147
# Epoch no. 15 |accuracy:  89.038 % |total_loss:  864.8149692951265
# Epoch no. 15 |accuracy:  89.056 % |total_loss:  865.2393651841703
# Epoch no. 15 |accuracy:  89.076 % |total_loss:  865.2635315502557
# Epoch no. 15 |accuracy:  89.094 % |total_loss:  865.8741324389848
# Epoch no. 15 |accuracy:  89.114 % |total_loss:  865.9847086290392
# Epoch no. 15 |accuracy:  89.134 % |total_loss:  866.0251378374669
# Epoch no. 15 |accuracy:  89.152 % |total_loss:  866.2175096827123
# Epoch no. 15 |accuracy:  89.17 % |total_loss:  866.4715406256291
# Epoch no. 15 |accuracy:  89.19 % |total_loss:  866.5521948667738
# Epoch no. 15 |accuracy:  89.206 % |total_loss:  866.8534502419207
# Epoch no. 15 |accuracy:  89.224 % |total_loss:  867.0396629753086
# Epoch no. 15 |accuracy:  89.24 % |total_loss:  867.4292721333477
# Epoch no. 15 |accuracy:  89.26 % |total_loss:  867.4698565783474
# Epoch no. 15 |accuracy:  89.28 % |total_loss:  867.5215115728352
# Epoch no. 15 |accuracy:  89.298 % |total_loss:  867.7163902404282
# Epoch no. 15 |accuracy:  89.318 % |total_loss:  867.7374987038347
# Epoch no. 15 |accuracy:  89.338 % |total_loss:  867.7528553087759
# Epoch no. 15 |accuracy:  89.358 % |total_loss:  867.7623496264714
# Epoch no. 15 |accuracy:  89.378 % |total_loss:  867.7946322545904
# Epoch no. 15 |accuracy:  89.396 % |total_loss:  867.9194657639164
# Epoch no. 15 |accuracy:  89.41 % |total_loss:  868.5856873825687
# Epoch no. 15 |accuracy:  89.43 % |total_loss:  868.6670347437757
# Epoch no. 15 |accuracy:  89.45 % |total_loss:  868.8232142612833
# Epoch no. 15 |accuracy:  89.47 % |total_loss:  868.8437891830254
# Epoch no. 15 |accuracy:  89.49 % |total_loss:  868.8546351813275
# Epoch no. 15 |accuracy:  89.504 % |total_loss:  869.3202638946968
# Epoch no. 15 |accuracy:  89.524 % |total_loss:  869.3375248224038
# Epoch no. 15 |accuracy:  89.542 % |total_loss:  869.6603575855988
# Epoch no. 15 |accuracy:  89.558 % |total_loss:  870.8288887650269
# Epoch no. 15 |accuracy:  89.576 % |total_loss:  871.5773182422417
# Epoch no. 15 |accuracy:  89.596 % |total_loss:  871.6255356953043
# Epoch no. 15 |accuracy:  89.612 % |total_loss:  872.1261108801264
# Epoch no. 15 |accuracy:  89.632 % |total_loss:  872.2103612855572
# Epoch no. 15 |accuracy:  89.65 % |total_loss:  872.3246476114291
# Epoch no. 15 |accuracy:  89.67 % |total_loss:  872.5074964225787
# Epoch no. 15 |accuracy:  89.688 % |total_loss:  872.7955503225821
# Epoch no. 15 |accuracy:  89.708 % |total_loss:  872.819700256412
# Epoch no. 15 |accuracy:  89.726 % |total_loss:  872.9775894288468
# Epoch no. 15 |accuracy:  89.746 % |total_loss:  872.9985783327866
# Epoch no. 15 |accuracy:  89.762 % |total_loss:  873.5387912024307
# Epoch no. 15 |accuracy:  89.782 % |total_loss:  873.6254765023041
# Epoch no. 15 |accuracy:  89.802 % |total_loss:  873.6628844295192
# Epoch no. 15 |accuracy:  89.822 % |total_loss:  873.6966147985804
# Epoch no. 15 |accuracy:  89.842 % |total_loss:  873.8762376126397
# Epoch no. 15 |accuracy:  89.862 % |total_loss:  873.9964656051743
# Epoch no. 15 |accuracy:  89.88 % |total_loss:  875.2990736183274
# Epoch no. 15 |accuracy:  89.898 % |total_loss:  875.454539668237
# Epoch no. 15 |accuracy:  89.916 % |total_loss:  875.6110594090569
# Epoch no. 15 |accuracy:  89.936 % |total_loss:  875.6285652522492
# Epoch no. 15 |accuracy:  89.954 % |total_loss:  875.7553499494243
# Epoch no. 15 |accuracy:  89.968 % |total_loss:  876.3234516535449
# Epoch no. 15 |accuracy:  89.986 % |total_loss:  876.6706921313453
# Epoch no. 15 |accuracy:  90.004 % |total_loss:  877.1345662925887
# Epoch no. 15 |accuracy:  90.024 % |total_loss:  877.1544117894518
# Epoch no. 15 |accuracy:  90.044 % |total_loss:  877.2080513205874
# Epoch no. 15 |accuracy:  90.06 % |total_loss:  877.6632406380522
# Epoch no. 15 |accuracy:  90.078 % |total_loss:  877.7693973448622
# Epoch no. 15 |accuracy:  90.094 % |total_loss:  878.3666400578368
# Epoch no. 15 |accuracy:  90.114 % |total_loss:  878.4006557133544
# Epoch no. 15 |accuracy:  90.13 % |total_loss:  879.3782461550582
# Epoch no. 15 |accuracy:  90.15 % |total_loss:  879.455304723655
# Epoch no. 15 |accuracy:  90.166 % |total_loss:  879.8727214750397
# Epoch no. 15 |accuracy:  90.182 % |total_loss:  880.1852776822197
# Epoch no. 15 |accuracy:  90.2 % |total_loss:  880.3174091693509
# Epoch no. 15 |accuracy:  90.218 % |total_loss:  880.5698165413487
# Epoch no. 15 |accuracy:  90.236 % |total_loss:  880.7701268163073
# Epoch no. 15 |accuracy:  90.254 % |total_loss:  880.9236154523242
# Epoch no. 15 |accuracy:  90.274 % |total_loss:  880.9353673564765
# Epoch no. 15 |accuracy:  90.294 % |total_loss:  880.9684753003094
# Epoch no. 15 |accuracy:  90.314 % |total_loss:  880.9930075867596
# Epoch no. 15 |accuracy:  90.332 % |total_loss:  881.3741246922436
# Epoch no. 15 |accuracy:  90.35 % |total_loss:  881.5488277389231
# Epoch no. 15 |accuracy:  90.37 % |total_loss:  881.665676006538
# Epoch no. 15 |accuracy:  90.39 % |total_loss:  881.7732334374014
# Epoch no. 15 |accuracy:  90.408 % |total_loss:  881.8732748492184
# Epoch no. 15 |accuracy:  90.426 % |total_loss:  882.2572524710122
# Epoch no. 15 |accuracy:  90.444 % |total_loss:  882.4648390723887
# Epoch no. 15 |accuracy:  90.464 % |total_loss:  882.563670986754
# Epoch no. 15 |accuracy:  90.482 % |total_loss:  882.7658724425855
# Epoch no. 15 |accuracy:  90.502 % |total_loss:  882.7836299514893
# Epoch no. 15 |accuracy:  90.52 % |total_loss:  882.9133436954144
# Epoch no. 15 |accuracy:  90.54 % |total_loss:  883.0009921914461
# Epoch no. 15 |accuracy:  90.558 % |total_loss:  883.1759815937403
# Epoch no. 15 |accuracy:  90.578 % |total_loss:  883.2073457180086
# Epoch no. 15 |accuracy:  90.598 % |total_loss:  883.276296721262
# Epoch no. 15 |accuracy:  90.616 % |total_loss:  883.477730662984
# Epoch no. 15 |accuracy:  90.634 % |total_loss:  883.7133396430436
# Epoch no. 15 |accuracy:  90.65 % |total_loss:  884.3554145260277
# Epoch no. 15 |accuracy:  90.668 % |total_loss:  884.629486577076
# Epoch no. 15 |accuracy:  90.688 % |total_loss:  884.6603040857735
# Epoch no. 15 |accuracy:  90.708 % |total_loss:  884.7021861574176
# Epoch no. 15 |accuracy:  90.728 % |total_loss:  884.8274571350339
# Epoch no. 15 |accuracy:  90.746 % |total_loss:  885.041515504432
# Epoch no. 15 |accuracy:  90.764 % |total_loss:  885.2500150850537
# Epoch no. 15 |accuracy:  90.782 % |total_loss:  885.4811929664138
# Epoch no. 15 |accuracy:  90.798 % |total_loss:  885.9105939766887
# Epoch no. 15 |accuracy:  90.818 % |total_loss:  885.9625043957058
# Epoch no. 15 |accuracy:  90.838 % |total_loss:  886.0146524807933
# Epoch no. 15 |accuracy:  90.852 % |total_loss:  886.7283624312404
# Epoch no. 15 |accuracy:  90.866 % |total_loss:  887.2858269116405
# Epoch no. 15 |accuracy:  90.884 % |total_loss:  887.4410708597425
# Epoch no. 15 |accuracy:  90.902 % |total_loss:  887.5910816690448
# Epoch no. 15 |accuracy:  90.92 % |total_loss:  887.7352642169717
# Epoch no. 15 |accuracy:  90.938 % |total_loss:  887.8771428367618
# Epoch no. 15 |accuracy:  90.958 % |total_loss:  888.0820988020423
# Epoch no. 15 |accuracy:  90.974 % |total_loss:  888.3686108192924
# Epoch no. 15 |accuracy:  90.992 % |total_loss:  888.6959575614455
# Epoch no. 15 |accuracy:  91.012 % |total_loss:  888.7674209824327
# Epoch no. 15 |accuracy:  91.03 % |total_loss:  889.0207242420438
# Epoch no. 15 |accuracy:  91.048 % |total_loss:  889.6477028778318
# Epoch no. 15 |accuracy:  91.068 % |total_loss:  889.7170607647422
# Epoch no. 15 |accuracy:  91.086 % |total_loss:  889.8785743615153
# Epoch no. 15 |accuracy:  91.106 % |total_loss:  889.9337927414599
# Epoch no. 15 |accuracy:  91.126 % |total_loss:  890.037815795702
# Epoch no. 15 |accuracy:  91.146 % |total_loss:  890.0674646920088
# Epoch no. 15 |accuracy:  91.166 % |total_loss:  890.1358569091681
# Epoch no. 15 |accuracy:  91.186 % |total_loss:  890.1444556735951
# Epoch no. 15 |accuracy:  91.206 % |total_loss:  890.1990072042245
# Epoch no. 15 |accuracy:  91.224 % |total_loss:  890.3771704942483
# Epoch no. 15 |accuracy:  91.24 % |total_loss:  890.7059590131539
# Epoch no. 15 |accuracy:  91.254 % |total_loss:  891.3603542954224
# Epoch no. 15 |accuracy:  91.272 % |total_loss:  891.6716170520085
# Epoch no. 15 |accuracy:  91.288 % |total_loss:  892.0355783910054
# Epoch no. 15 |accuracy:  91.306 % |total_loss:  892.1485437810916
# Epoch no. 15 |accuracy:  91.326 % |total_loss:  892.1699370895076
# Epoch no. 15 |accuracy:  91.344 % |total_loss:  892.3351054642844
# Epoch no. 15 |accuracy:  91.362 % |total_loss:  892.5940170441318
# Epoch no. 15 |accuracy:  91.382 % |total_loss:  892.6307517257083
# Epoch no. 15 |accuracy:  91.4 % |total_loss:  892.9745989706862
# Epoch no. 15 |accuracy:  91.42 % |total_loss:  892.9953911085177
# Epoch no. 15 |accuracy:  91.438 % |total_loss:  893.1281634498882
# Epoch no. 15 |accuracy:  91.456 % |total_loss:  893.3336912323284
# Epoch no. 15 |accuracy:  91.476 % |total_loss:  893.3847888451564
# Epoch no. 15 |accuracy:  91.494 % |total_loss:  893.5447389524925
# Epoch no. 15 |accuracy:  91.512 % |total_loss:  893.7796660405147
# Epoch no. 15 |accuracy:  91.53 % |total_loss:  893.9426385056722
# Epoch no. 15 |accuracy:  91.548 % |total_loss:  894.2869137716043
# Epoch no. 15 |accuracy:  91.568 % |total_loss:  894.3798280995834
# Epoch no. 15 |accuracy:  91.586 % |total_loss:  894.6155083220947
# Epoch no. 15 |accuracy:  91.604 % |total_loss:  894.8118591946113
# Epoch no. 15 |accuracy:  91.618 % |total_loss:  895.149767164563
# Epoch no. 15 |accuracy:  91.638 % |total_loss:  895.232156355356
# Epoch no. 15 |accuracy:  91.658 % |total_loss:  895.3055887263763
# Epoch no. 15 |accuracy:  91.676 % |total_loss:  895.4134864252555
# Epoch no. 15 |accuracy:  91.692 % |total_loss:  895.7714922767627
# Epoch no. 15 |accuracy:  91.71 % |total_loss:  896.0990153592575
# Epoch no. 15 |accuracy:  91.73 % |total_loss:  896.1043823812652
# Epoch no. 15 |accuracy:  91.75 % |total_loss:  896.127754163419
# Epoch no. 15 |accuracy:  91.77 % |total_loss:  896.1711847227562
# Epoch no. 15 |accuracy:  91.79 % |total_loss:  896.1858088881272
# Epoch no. 15 |accuracy:  91.81 % |total_loss:  896.2543152928847
# Epoch no. 15 |accuracy:  91.826 % |total_loss:  896.5022741467255
# Epoch no. 15 |accuracy:  91.842 % |total_loss:  896.7664162129659
# Epoch no. 15 |accuracy:  91.862 % |total_loss:  896.9025638908643
# Epoch no. 15 |accuracy:  91.882 % |total_loss:  896.9669330329198
# Epoch no. 15 |accuracy:  91.902 % |total_loss:  897.0416781068343
# Epoch no. 15 |accuracy:  91.92 % |total_loss:  897.2577417701978
# Epoch no. 15 |accuracy:  91.936 % |total_loss:  897.7658751816052
# Epoch no. 15 |accuracy:  91.954 % |total_loss:  898.2895162314671
# Epoch no. 15 |accuracy:  91.972 % |total_loss:  898.4825014979142
# Epoch no. 15 |accuracy:  91.99 % |total_loss:  898.7312785298127
# Epoch no. 15 |accuracy:  92.01 % |total_loss:  898.7710559279221
# Epoch no. 15 |accuracy:  92.026 % |total_loss:  899.168564549138
# Epoch no. 15 |accuracy:  92.046 % |total_loss:  899.1850127935904
# Epoch no. 15 |accuracy:  92.066 % |total_loss:  899.2284368560213
# Epoch no. 15 |accuracy:  92.086 % |total_loss:  899.2978526190418
# Epoch no. 15 |accuracy:  92.102 % |total_loss:  899.6300244167942
# Epoch no. 15 |accuracy:  92.122 % |total_loss:  899.7194252446789
# Epoch no. 15 |accuracy:  92.14 % |total_loss:  899.9071595803398
# Epoch no. 15 |accuracy:  92.154 % |total_loss:  900.4693073168892
# Epoch no. 15 |accuracy:  92.174 % |total_loss:  900.5205356129009
# Epoch no. 15 |accuracy:  92.194 % |total_loss:  900.5965396859247
# Epoch no. 15 |accuracy:  92.214 % |total_loss:  900.7421178617078
# Epoch no. 15 |accuracy:  92.23 % |total_loss:  900.9877060898143
# Epoch no. 15 |accuracy:  92.25 % |total_loss:  901.0592968784767
# Epoch no. 15 |accuracy:  92.268 % |total_loss:  901.6066329800087
# Epoch no. 15 |accuracy:  92.286 % |total_loss:  901.8777274810273
# Epoch no. 15 |accuracy:  92.306 % |total_loss:  901.9116069213051
# Epoch no. 15 |accuracy:  92.326 % |total_loss:  901.912467098402
# Epoch no. 15 |accuracy:  92.344 % |total_loss:  902.0562843145599
# Epoch no. 15 |accuracy:  92.362 % |total_loss:  902.3202169598808
# Epoch no. 15 |accuracy:  92.38 % |total_loss:  902.5311561288108
# Epoch no. 15 |accuracy:  92.4 % |total_loss:  902.6334601701965
# Epoch no. 15 |accuracy:  92.418 % |total_loss:  902.8388201357593
# Epoch no. 15 |accuracy:  92.436 % |total_loss:  902.9961893619766
# Epoch no. 15 |accuracy:  92.454 % |total_loss:  903.2836631299724
# Epoch no. 15 |accuracy:  92.474 % |total_loss:  903.3271060684492
# Epoch no. 15 |accuracy:  92.49 % |total_loss:  903.7586242357065
# Epoch no. 15 |accuracy:  92.51 % |total_loss:  903.7737191417982
# Epoch no. 15 |accuracy:  92.53 % |total_loss:  903.7993793045898
# Epoch no. 15 |accuracy:  92.548 % |total_loss:  903.9744975274225
# Epoch no. 15 |accuracy:  92.566 % |total_loss:  904.2705470924993
# Epoch no. 15 |accuracy:  92.584 % |total_loss:  904.4728749846836
# Epoch no. 15 |accuracy:  92.6 % |total_loss:  905.0680378531833
# Epoch no. 15 |accuracy:  92.62 % |total_loss:  905.2376921927353
# Epoch no. 15 |accuracy:  92.636 % |total_loss:  905.9599933778663
# Epoch no. 15 |accuracy:  92.656 % |total_loss:  906.0672418257018
# Epoch no. 15 |accuracy:  92.676 % |total_loss:  906.0697324174253
# Epoch no. 15 |accuracy:  92.694 % |total_loss:  906.2843846278993
# Epoch no. 15 |accuracy:  92.71 % |total_loss:  906.6337314742414
# Epoch no. 15 |accuracy:  92.726 % |total_loss:  907.2567415135709
# Epoch no. 15 |accuracy:  92.742 % |total_loss:  907.7569427388516
# Epoch no. 15 |accuracy:  92.758 % |total_loss:  907.9816973852721
# Epoch no. 15 |accuracy:  92.778 % |total_loss:  908.1111154305545
# Epoch no. 15 |accuracy:  92.794 % |total_loss:  908.4594472694007
# Epoch no. 15 |accuracy:  92.814 % |total_loss:  908.4603928131546
# Epoch no. 15 |accuracy:  92.83 % |total_loss:  909.2827067775215
# Epoch no. 15 |accuracy:  92.848 % |total_loss:  909.7747145099129
# Epoch no. 15 |accuracy:  92.868 % |total_loss:  909.8956470889534
# Epoch no. 15 |accuracy:  92.888 % |total_loss:  909.9755124626245
# Epoch no. 15 |accuracy:  92.908 % |total_loss:  909.9896464207704
# Epoch no. 15 |accuracy:  92.922 % |total_loss:  910.7104614832933
# Epoch no. 15 |accuracy:  92.94 % |total_loss:  910.9697947958048
# Epoch no. 15 |accuracy:  92.956 % |total_loss:  911.2965530016954
# Epoch no. 15 |accuracy:  92.974 % |total_loss:  911.4375363001163
# Epoch no. 15 |accuracy:  92.992 % |total_loss:  911.7466890522774
# Epoch no. 15 |accuracy:  93.008 % |total_loss:  912.2695465990837
# Epoch no. 15 |accuracy:  93.024 % |total_loss:  912.5622797915275
# Epoch no. 15 |accuracy:  93.042 % |total_loss:  912.7632905253704
# Epoch no. 15 |accuracy:  93.062 % |total_loss:  912.8297361516888
# Epoch no. 15 |accuracy:  93.078 % |total_loss:  913.1518173301156
# Epoch no. 15 |accuracy:  93.094 % |total_loss:  913.7034592115815
# Epoch no. 15 |accuracy:  93.112 % |total_loss:  913.8266854146059
# Epoch no. 15 |accuracy:  93.13 % |total_loss:  914.0563608565863
# Epoch no. 15 |accuracy:  93.148 % |total_loss:  914.3856299677427

# %% [markdown]
# Save the model

# %%
torch.save(model.state_dict(), r'/content/drive/MyDrive/Assignment 4/Weights5.pth')

# %% [markdown]
# Test the model over 'n' tries

# %%
model.eval()
predictions = []
num_test = 10
start = 100
with torch.no_grad():
  for test in range(len(test_images)):
      img = torch.tensor(test_images[test]).float() / 255
      img = img.unsqueeze(0).unsqueeze(0)

      confidence = model(img).tolist()[0]
      prediction = confidence.index(max(confidence))
      predictions.append(prediction)

      # print('Predicted Label:', label_str[int(prediction)])
      # show_image(test_images[test])
      # print('\n')

# %% [markdown]
# Save the prediction results of the testing set

# %%
import csv

with open(r'/content/drive/MyDrive/Assignment 4/submission4.csv', 'w', newline='') as f:
  writer = csv.writer(f)
  writer.writerow(['ID', 'label'])
  for i in range(len(predictions)):
    writer.writerow([i, predictions[i]])

# %% [markdown]
# The cell below is for testing purposes

# %%
print(len(predictions))
# Out:
# 20000
